# %% [markdown]
# Consider following code to answer further questions:
# ```
# import pandas as pd
# course_name = ['Data Science’, 'Machine Learning’, 'Big Data’, 'Data Engineer’]
# duration = [2,3,6,4]
# df = pd.DataFrame(data = {'course_name’ : course_name, 'duration’ : duration})
# ```

# %% [markdown]
# #### Q1. Write a code to print the data present in the second row of the dataframe, df.

# %%
import pandas as pd
course_name = ['Data Science', 'Machine Learning', 'Big Data', 'Data Engineer']
duration = [2,3,6,4]

df = pd.DataFrame(data = {'course_name' : course_name, 'duration' : duration})
df
# Out:
#         course_name  duration
# 0      Data Science         2
# 1  Machine Learning         3
# 2          Big Data         6
# 3     Data Engineer         4

# %%
# second row of the dataframe

print(df.iloc[[2]])

df.iloc[2,:] # another way
# Out:
#   course_name  duration
# 2    Big Data         6
# course_name    Big Data
# duration              6
# Name: 2, dtype: object

# %% [markdown]
# #### Q2. What is the difference between the functions `loc` and `iloc` in pandas.DataFrame?

# %% [markdown]
# `loc` helps in fetchign the records from the dataframe based on the label name (of row and column)
#
# `iloc` helps in fetching the records from the dataframe based on the index
#
# Some exmaple code is given below:

# %%
test = pd.DataFrame([[1, 2], [4, 5], [7, 8], [11, 22], [33, 44]],
index=['r1', 'r2', 'r3', 'r4', 'r5'],
columns=['num1', 'num2'])

test
# Out:
#     num1  num2
# r1     1     2
# r2     4     5
# r3     7     8
# r4    11    22
# r5    33    44

# %%
test.loc[['r1', 'r2']]
# Out:
#     num1  num2
# r1     1     2
# r2     4     5

# %%
test.loc['r1', 'num2']  # row label-'r1', along woth column label-'num2'
# Out:
# 2

# %%
test.loc['r2':'r5', 'num2']
# Out:
# r2     5
# r3     8
# r4    22
# r5    44
# Name: num2, dtype: int64

# %%
test.iloc[[3]]  # getting a particual row based on its index number
# Out:
#     num1  num2
# r4    11    22

# %%
test.iloc[[0,4],[1]] # fetchng 2 rows and 1 column
# Out:
#     num2
# r1     2
# r5    44

# %%
# slicing 3 rows and all columns

test.iloc[:3,:]
# Out:
#     num1  num2
# r1     1     2
# r2     4     5
# r3     7     8

# %%
# slicing from 3rd row to last row and all columns

test.iloc[2:,:]
# Out:
#     num1  num2
# r3     7     8
# r4    11    22
# r5    33    44

# %% [markdown]
# #### Q3. Reindex the given dataframe using a variable, `reindex = [3,0,1,2]` and store it in the variable, `new_df` then find the output for both `new_df.loc[2]` and `new_df.iloc[2]`.
#
# #### Did you observe any difference in both the outputs? If so then explain it.

# %%
df.head()
# Out:
#         course_name  duration
# 0      Data Science         2
# 1  Machine Learning         3
# 2          Big Data         6
# 3     Data Engineer         4

# %%
new_df = df.reindex(index = [3,0,1,2])
new_df
# Out:
#         course_name  duration
# 3     Data Engineer         4
# 0      Data Science         2
# 1  Machine Learning         3
# 2          Big Data         6

# %%
new_df.loc[[2]]
# Out:
#   course_name  duration
# 2    Big Data         6

# %%
new_df.iloc[[2]]
# Out:
#         course_name  duration
# 1  Machine Learning         3

# %% [markdown]
# when the code `new_df.loc[[2]]` is run, python will search for the record that has the row named with the label `"2"` and fetch that record.
#
# On the other had when the code `new_df.iloc[[2]]` is run, python search the record which is at **index** number `2` and fetch that record. *the indexing is 0 based*

# %% [markdown]
# #### Q4. Write a code to find the following statistical measurements for the above dataframe df1:
# #### (i) mean of each and every column present in the dataframe.
# #### (ii) standard deviation of column, ‘column_2’
#
# #### Consider the below code to answer further questions:
# ```
# import pandas as pd
# import numpy as np
# columns = ['column_1', 'column_2', 'column_3', 'column_4', 'column_5', 'column_6']
# indices = [1,2,3,4,5,6]
# # Creating a dataframe:
# df1 = pd.DataFrame(np.random.rand(6,6), columns = columns, index = indices)
# ```

# %%
import pandas as pd
import numpy as np
columns = ['column_1', 'column_2', 'column_3', 'column_4', 'column_5', 'column_6']
indices = [1,2,3,4,5,6]
# Creating a dataframe:

df1 = pd.DataFrame(np.random.rand(6,6), columns = columns, index = indices)

df1
# Out:
#    column_1  column_2  column_3  column_4  column_5  column_6
# 1  0.915794  0.748561  0.880019  0.635437  0.374753  0.100364
# 2  0.352573  0.092328  0.127197  0.163797  0.056256  0.887605
# 3  0.495518  0.976498  0.924146  0.277410  0.035126  0.008960
# 4  0.109371  0.890218  0.242020  0.368106  0.484371  0.520071
# 5  0.780125  0.668261  0.674769  0.981395  0.458429  0.381487
# 6  0.576658  0.359969  0.467669  0.835925  0.130470  0.607710

# %% [markdown]
# #### (i) mean of each and every column present in the dataframe.

# %%
df1.describe().loc[['mean']]
# Out:
#       column_1  column_2  column_3  column_4  column_5  column_6
# mean   0.53834  0.622639  0.552637  0.543678  0.256568  0.417699

# %% [markdown]
# #### (ii) standard deviation of column, ‘column_2’

# %%
df1.describe().loc[['std'], ['column_2']]
# Out:
#      column_2
# std  0.336148

# %%
df1.describe().iloc[[2],[1]]
# Out:
#      column_2
# std  0.336148

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6 entries, 1 to 6
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   column_1  6 non-null      float64
#  1   column_2  6 non-null      float64
#  2   column_3  6 non-null      float64
#  3   column_4  6 non-null      float64
#  4   column_5  6 non-null      float64
#  5   column_6  6 non-null      float64
# dtypes: float64(6)
# memory usage: 336.0 bytes

# %% [markdown]
# #### Q5. Replace the data present in the second row of column, ‘column_2’ by a string variable then find the mean of column, column_2.
# #### If you are getting errors in executing it then explain why.
# [Hint: To replace the data use `df1.loc[]` and equate this to string data of your choice.]

# %%
df1.loc[[2], ['column_2']] = "HelloWorld"
# another way to do the above is using .iloc ==> df1.iloc[[1], [1]] = "LaLaLa"
df1
# Out:
#    column_1    column_2  column_3  column_4  column_5  column_6
# 1  0.915794    0.748561  0.880019  0.635437  0.374753  0.100364
# 2  0.352573  HelloWorld  0.127197  0.163797  0.056256  0.887605
# 3  0.495518    0.976498  0.924146  0.277410  0.035126  0.008960
# 4  0.109371    0.890218  0.242020  0.368106  0.484371  0.520071
# 5  0.780125    0.668261  0.674769  0.981395  0.458429  0.381487
# 6  0.576658    0.359969  0.467669  0.835925  0.130470  0.607710

# %%
df1.describe()
# Out:
#        column_1  column_3  column_4  column_5  column_6
# count  6.000000  6.000000  6.000000  6.000000  6.000000
# mean   0.538340  0.552637  0.543678  0.256568  0.417699
# std    0.290777  0.330095  0.326024  0.205753  0.327560
# min    0.109371  0.127197  0.163797  0.035126  0.008960
# 25%    0.388309  0.298433  0.300084  0.074809  0.170644
# 50%    0.536088  0.571219  0.501772  0.252612  0.450779
# 75%    0.729258  0.828706  0.785803  0.437510  0.585800
# max    0.915794  0.924146  0.981395  0.484371  0.887605

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6 entries, 1 to 6
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   column_1  6 non-null      float64
#  1   column_2  6 non-null      object
#  2   column_3  6 non-null      float64
#  3   column_4  6 non-null      float64
#  4   column_5  6 non-null      float64
#  5   column_6  6 non-null      float64
# dtypes: float64(5), object(1)
# memory usage: 508.0+ bytes

# %%
df1.describe().loc[['std'], ['column_2']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 df1.describe().loc[['std'], ['column_2']]
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1147, in _LocIndexer._getitem_tuple(self, tup)
#    1145 # ugly hack for GH #836
#    1146 if self._multi_take_opportunity(tup):
# -> 1147     return self._multi_take(tup)
#    1149 return self._getitem_tuple_same_dim(tup)
#
# ...

# %% [markdown]
# #### ANSWER:
# Once the 2nd row of the column- `column_2` is replaced with a string type object then the datatype of the `column_2` gets changed from `float64` to `Object` and any predictor which has string/object data type cannot have a Standard Deviation since, its a numerical statistical value. As a result of whihc after `Float64` to `Object` conversion, when `df1.info()` is run, the `column_2` is ommited from the result!

# %% [markdown]
# #### Q6. What do you understand about the windows function in pandas and list the types of windows functions?

# %% [markdown]
# The Window function are function which take a small piece of the data and perform some calculation on it. The selection of the data subset done using a sliding window which is like a frame that moves/slide over the range of the data.
#
# _Simple example to relate this 'sliding window' over the dataset is : A Vernier Calliper, which has a small frame that shows the part of the points on the scale over which it slided._
#
# _see the arrow pointing to a **'sliding window'** on the **vernier caliper**_
#
# ![image.png](attachment:image.png)
#
# In a similar way, the subset of the dataset is picked and performed calculation over it.
#
#
# There are different types of window function available in pandas:
#
# __1.) rolling window:__
#
# * The rolling window function is used to perform calculations over a specified window of data points.
# *
# It is often used for tasks like calculating moving averages or other rolling statistics
# * The size of the sliding window is fixed every time.
# *
# Here's an example of how to calculate the 3-day rolling mean of a time series using Pandas:

# %%
# rolling window

some_dataset = pd.DataFrame({
    "dates" : pd.date_range(start = '1989-06-30', freq = 'M', periods = 20),
    "sales" : np.random.randint(low = 10, high = 200, size = 20)
})

some_dataset
# Out:
#         dates  sales
# 0  1989-06-30    168
# 1  1989-07-31    101
# 2  1989-08-31    168
# 3  1989-09-30    187
# 4  1989-10-31     62
# 5  1989-11-30    132
# 6  1989-12-31    130
# 7  1990-01-31    141
# 8  1990-02-28     72
# 9  1990-03-31    168
# 10 1990-04-30     10
# 11 1990-05-31    128
# 12 1990-06-30     53
# 13 1990-07-31    162
# 14 1990-08-31     13
# 15 1990-09-30    163
# 16 1990-10-31     37
# 17 1990-11-30     24
# 18 1990-12-31     46
# 19 1991-01-31     97

# %%
some_dataset['roll_win_avg'] = round(some_dataset['sales'].rolling(window = 3, min_periods= 1).mean(), 2)
some_dataset.head(10)
# Out:
#        dates  sales  roll_win_avg
# 0 1989-06-30    168        168.00
# 1 1989-07-31    101        134.50
# 2 1989-08-31    168        145.67
# 3 1989-09-30    187        152.00
# 4 1989-10-31     62        139.00
# 5 1989-11-30    132        127.00
# 6 1989-12-31    130        108.00
# 7 1990-01-31    141        134.33
# 8 1990-02-28     72        114.33
# 9 1990-03-31    168        127.00

# %% [markdown]
# __2.) Expanding Window__
#
# While the `rolling window` moves along the data with a fixed-size window, the `expanding window` continuously expands to include more and more data as it moves along. It calculates some statistic over all data points seen so far.r..

# %%
some_dataset['expanding_win_avg'] = some_dataset['sales'].expanding().mean()
some_dataset
# Out:
#         dates  sales  roll_win_avg  expanding_win_avg
# 0  1989-06-30    168        168.00         168.000000
# 1  1989-07-31    101        134.50         134.500000
# 2  1989-08-31    168        145.67         145.666667
# 3  1989-09-30    187        152.00         156.000000
# 4  1989-10-31     62        139.00         137.200000
# 5  1989-11-30    132        127.00         136.333333
# 6  1989-12-31    130        108.00         135.428571
# 7  1990-01-31    141        134.33         136.125000
# 8  1990-02-28     72        114.33         129.000000
# 9  1990-03-31    168        127.00         132.900000
# 10 1990-04-30     10         83.33         121.727273
# 11 1990-05-31    128        102.00         122.250000
# 12 1990-06-30     53         63.67         116.923077
# 13 1990-07-31    162        114.33         120.142857
# 14 1990-08-31     13         76.00         113.000000
# 15 1990-09-30    163        112.67         116.125000
# ...

# %% [markdown]
# __3.) Exponentially Weighted Moving Average (ewm):__
#
# The `ewm` function calculates the exponentially weighted moving average, giving more weight to recent data points. It is useful for capturing short-term trends while dampening the impact of older observatios
#
# .
# The `span` parameter is used to specify the time period for exponential weighting__

# %%
import pandas as pd

# Create a DataFrame with daily temperature readings
data = {'Date': pd.date_range(start='2023-01-01', periods=10),
        'Temperature': [25, 27, 26, 24, 28, 29, 30, 31, 32, 30]}
df = pd.DataFrame(data)

# Set the 'Date' column as the index
df.set_index('Date', inplace=True)

print(df)
print("="*50)

# Calculate the exponentially weighted mean of temperature
ewma = df['Temperature'].ewm(span=3, adjust=False).mean()
print(ewma)
# Out:
#             Temperature
# Date
# 2023-01-01           25
# 2023-01-02           27
# 2023-01-03           26
# 2023-01-04           24
# 2023-01-05           28
# 2023-01-06           29
# 2023-01-07           30
# 2023-01-08           31
# 2023-01-09           32
# 2023-01-10           30
# ...
# Date
# 2023-01-01    25.000000
# 2023-01-02    26.000000
# 2023-01-03    26.000000
# 2023-01-04    25.000000
# 2023-01-05    26.500000
# 2023-01-06    27.750000
# 2023-01-07    28.875000
# 2023-01-08    29.937500
# 2023-01-09    30.968750
# 2023-01-10    30.484375
# Name: Temperature, dtype: float64

# %% [markdown]
# ### Q7. Write a code to print only the current month and year at the time of answering this question.
# [Hint: Use pandas.datetime function]

# %%
current_timestamp = pd.Timestamp.now()
print("current_datetime:" , current_timestamp)

curr_month = current_timestamp.month
curr_year = current_timestamp.year

print("current month: ", curr_month)
print("current_year :", curr_year)
# Out:
# current_datetime: 2024-02-25 14:52:01.842843
# current month:  2
# current_year : 2024

# %% [markdown]
# #### Q8. Write a Python program that takes in two dates as input (in the format YYYY-MM-DD) and calculates the difference between them in days, hours, and minutes using Pandas time delta. The program should prompt the user to enter the dates and display the result.

# %%
import pandas as pd

cols = ['diff_in_days', 'diff_in_hours', 'diff_in_mins']


some_date1 = input("Enter date in the format yyyy-mm-dd: ") #'1989-06-01'
some_date2 = input("Enter date in the format yyyy-mm-dd: ") #'1989-06-03'

date_diff = pd.DataFrame({"dob1": [pd.to_datetime(some_date1).date()],
                          "dob2" : [pd.to_datetime(some_date2).date()]})

date_diff['diff_in_days'] = abs(date_diff['dob1'].iloc[0] - date_diff['dob2'].iloc[0]).days
date_diff['diff_in_hours'] = abs(date_diff['dob1'].iloc[0] - date_diff['dob2'].iloc[0]).days*24
date_diff['diff_in_mins'] =  abs(date_diff['dob1'].iloc[0] - date_diff['dob2'].iloc[0]).days*24*60

date_diff
# Out:
# Enter date in the format yyyy-mm-dd: 1989-06-30
# Enter date in the format yyyy-mm-dd: 1984-08-02
#          dob1        dob2  diff_in_days  diff_in_hours  diff_in_mins
# 0  1989-06-30  1984-08-02          1793          43032       2581920

# %% [markdown]
# #### Q9. Write a Python program that reads a CSV file containing categorical data and converts a specified column to a categorical data type. The program should prompt the user to enter the file path, column name, and category order, and then display the sorted data.

# %%
filepath = input("Enter csv file path: ")
catg_col_name = input("Enter the column name: ")
cat_order = input("Enter the category order (comma seperated): ").split(",")

df9 = pd.read_csv(filepath_or_buffer= filepath)
print(df9.info(),"\n\n")
df9[catg_col_name] = pd.Categorical(values = df9[catg_col_name].to_list(), categories = ['defunct', 'active', 'inactive'])

df9.info()
# Out:
# Enter csv file path: D:\PWSkills_DS_Masters\services.csv
# Enter the column name: status
# Enter the category order (comma seperated): defunct,inactive,active
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       23 non-null     int64
#  1   location_id              23 non-null     int64
#  2   program_id               0 non-null      float64
#  3   accepted_payments        1 non-null      object
#  4   alternate_name           1 non-null      object
#  5   application_process      23 non-null     object
#  6   audience                 14 non-null     object
#  7   description              23 non-null     object
#  8   eligibility              21 non-null     object
#  9   email                    1 non-null      object
#  10  fees                     21 non-null     object
# ...

# %% [markdown]
# #### Q10. Write a Python program that reads a CSV file containing sales data for different products and visualizes the data using a stacked bar chart to show the sales of each product category over time. The program should prompt the user to enter the file path and display the chart.

# %%
dataset_path = input("File path: ") # D:\Github\PWSkills-Data-Science-Masters\Pandas\q10-sales.csv
df10 = pd.read_csv(dataset_path)

print(df10.head(20))

# df10.plot(x = 'Date', y = 'Sales', kind = 'bar',
#           stacked = True, figsize = (35,15)
#          )


#df10.plot.bar(x = 'Date', y = 'Sales', figsize = (35, 10))
# Out:
# File path: D:\Github\PWSkills-Data-Science-Masters\Pandas\q10-sales.csv
#           Date Product_Category  Sales
# 0   2022-01-01       Category A   1646
# 1   2022-01-01       Category B    687
# 2   2022-01-01       Category C   1607
# 3   2022-01-02       Category A    763
# 4   2022-01-02       Category B   1375
# 5   2022-01-02       Category C   1850
# 6   2022-01-03       Category A   1526
# 7   2022-01-03       Category B   1741
# 8   2022-01-03       Category C   1832
# 9   2022-01-04       Category A   1090
# 10  2022-01-04       Category B   1329
# 11  2022-01-04       Category C   1641
# 12  2022-01-05       Category A   1686
# 13  2022-01-05       Category B   1427
# 14  2022-01-05       Category C   1080
# 15  2022-01-06       Category A   1805
# 16  2022-01-06       Category B   1599
# 17  2022-01-06       Category C   1066
# 18  2022-01-07       Category A   1618
# 19  2022-01-07       Category B   1874

# %%
new_df = df10.pivot(index='Date', columns='Product_Category', values='Sales')#.reset_index()
new_df.columns.name = None
new_df = new_df.rename(columns={'Category A': 'Sales_Category_A',
                                'Category B': 'Sales_Category_B',
                                'Category C': 'Sales_Category_C'})

new_df.head()
# Out:
# Product_Category  Sales_Category_A  Sales_Category_B  Sales_Category_C
# Date
# 2022-01-01                    1646               687              1607
# 2022-01-02                     763              1375              1850
# 2022-01-03                    1526              1741              1832
# 2022-01-04                    1090              1329              1641
# 2022-01-05                    1686              1427              1080

# %%
# creating a new dataframe that will have categories as column, so that we can create a stacked bar chart of sales.

catg2col = df10['Product_Category'].unique().tolist()
new_df10 = pd.DataFrame(columns= ['Date']+catg2col)

new_df10['Date'] = df10['Date'].unique()

for cat in catg2col:
    catg_values_per_date = []
    for dt in new_df10['Date'].tolist():
        catg_values_per_date.append(df10[(df10['Product_Category'] == cat) & (df10['Date'] == dt)].iloc[0, 2])
        
    new_df10[cat] = catg_values_per_date

new_df10.head()
# Out:
#          Date  Category A  Category B  Category C
# 0  2022-01-01        1646         687        1607
# 1  2022-01-02         763        1375        1850
# 2  2022-01-03        1526        1741        1832
# 3  2022-01-04        1090        1329        1641
# 4  2022-01-05        1686        1427        1080

# %%
new_df10.plot(x = 'Date', y = ['Category A','Category B','Category C'],
              kind = 'bar',
              stacked = True,
             figsize = (25, 15),
             ylabel = "------------- Sales -------------",
             xlabel = "------------- Datum -------------",
             title = "LaLaLa Sales",
             grid = True)
# Out:
# <AxesSubplot:title={'center':'LaLaLa Sales'}, xlabel='------------- Datum -------------', ylabel='------------- Sales -------------'>

# %% [markdown]
# #### Q11. You are given a CSV file containing student data that includes the student ID and their test score. Write a Python program that reads the CSV file, calculates the mean, median, and mode of the test scores, and displays the results in a table.

# %%
student_data = pd.read_csv("D:\Github\PWSkills-Data-Science-Masters\Pandas\student_samples.csv")
student_data
# Out:
#    student_id  test_score
# 0      std001          87
# 1      std002          50
# 2      std003          59
# 3      std004          43
# 4      std005          51
# 5      std006          51
# 6      std007          30
# 7      std008          73
# 8      std009          52
# 9      std010          41
# 10     std011          20
# 11     std012          46
# 12     std013          44
# 13     std014          20
# 14     std015          85
# 15     std016          44
# 16     std017          76
# 17     std018          53

# %%
student_stats = pd.DataFrame(columns = ['Mean', 'Median', 'Mode'])
student_stats['Mean'] = student_data.test_score.mean()
student_stats['Median'] = student_data.test_score.median()
student_stats['Mode'] = student_data.test_score.mode().to_numpy()

student_stats
# Out:
#    Mean  Median  Mode
# 0   NaN     NaN    20
# 1   NaN     NaN    44
# 2   NaN     NaN    51

# %%
student_data.test_score.mode()
# Out:
# 0    20
# 1    44
# 2    51
# Name: test_score, dtype: int64
