# %% [markdown]
# ### Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# Flask is python based framework which is used for web based application development in python language.
#
# __Advantages:__<br>
# * Flask is easy to learn and pick up by newbies
# * Easy to setup and use
# * Higher compatibilty with latest technologies
# * Easy to build a quick prototype of the web applcaiton.

# %% [markdown]
# ### Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/greeting/<username>")
def greet(username):
    return "<b>Hello World! {}</b>".format(username)



if __name__ == "__main__":
    app.run(host = "0.0.0.0")
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on all addresses.
#    WARNING: This is a development server. Do not use it in a production deployment.
#  * Running on http://192.168.29.193:5000/ (Press CTRL+C to quit)
# 192.168.29.193 - - [23/Nov/2023 15:39:29] "GET / HTTP/1.1" 404 -
# 192.168.29.193 - - [23/Nov/2023 15:39:30] "GET /favicon.ico HTTP/1.1" 404 -
# 192.168.29.193 - - [23/Nov/2023 15:39:40] "GET / HTTP/1.1" 404 -
# 192.168.29.193 - - [23/Nov/2023 15:40:08] "GET /greeting/Adarsh%20Namdev HTTP/1.1" 200 -

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Q3. What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# Clients such as web browsers send requests to the web server, which in turn sends them to the Flask application instance.
#
# The Flask application instance needs to know what code it needs to run for each URL requested, so it keeps a mapping of URLs to Python functions.
#
# The most convenient way to define a route in a Flask application is through the app.route decorator exposed by the application instance.
#
# A route is the association between a URL and the function that handles it
#
# App routing is used to map the specific URL with the associated function that is intended to perform some task.
# The routing technique helps a user remember application URLs and is useful to access the desired page directly without having to navigate from the home page.
#
# The `route()` decorator in Flask is used to bind URL to a function.

# %% [markdown]
# ### Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/” route to show the following details:
#
# __Company Name: ABC Corporation__<br>
# __Location: India__<br>
# __Contact Detail: 999-999-9999__

# %%
from flask import Flask
from flask import url_for

app = Flask(__name__)

@app.route("/")
def homepage():
    return """
    <b>Company Name   : ABC Corporation </b><br>
    <b>Location       : India </b><br>
    <b>Contact Detail : 999-999-9999</b>
    """

@app.route("/welcome")
def wilkommen():
    return "Welcome to ABC Corporation"


with app.test_request_context():
    dynamic_url = url_for(endpoint = "wilkommen", ram='JaiShriRam', radhe='JaiShreeRadhe', baba='HarHarMahadev')
    print(dynamic_url)
    

app.run(host = "0.0.0.0")
# Out:
# /welcome?ram=JaiShriRam&radhe=JaiShreeRadhe&baba=HarHarMahadev
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on all addresses.
#    WARNING: This is a development server. Do not use it in a production deployment.
#  * Running on http://192.168.29.193:5000/ (Press CTRL+C to quit)
# 192.168.29.193 - - [24/Nov/2023 13:38:21] "GET / HTTP/1.1" 200 -
# 192.168.29.193 - - [24/Nov/2023 13:38:59] "GET //welcome?ram=JaiShriRam&radhe=JaiShreeRadhe&baba=HarHarMahadev HTTP/1.1" 200 -

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.

# %% [markdown]
# In Flask, the `url_for()` function is used to dynamically build a URL for a specific function or endpoint in your application. This function generates a URL based on the endpoint name (i.e. the function name) and any arguments you provide, ensuring that your application's routes are referenced in a consistent and maintainable way.

# %%
from flask import Flask
from flask import url_for

app = Flask(__name__)

@app.route("/")
def homepage():
    return """
    <b>Company Name   : ABC Corporation </b><br>
    <b>Location       : India </b><br>
    <b>Contact Detail : 999-999-9999</b>
    """

@app.route("/welcome")
def wilkommen():
    return "Welcome to ABC Corporation"


with app.test_request_context():
    dynamic_url = url_for(endpoint = "wilkommen", ram='JaiShriRam', radhe='JaiShreeRadhe', baba='HarHarMahadev')
    print(dynamic_url)
    

app.run(host = "0.0.0.0")
# Out:
# /welcome?ram=JaiShriRam&radhe=JaiShreeRadhe&baba=HarHarMahadev
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on all addresses.
#    WARNING: This is a development server. Do not use it in a production deployment.
#  * Running on http://192.168.29.193:5000/ (Press CTRL+C to quit)
# 192.168.29.193 - - [24/Nov/2023 13:40:31] "GET /welcome?ram=JaiShriRam&radhe=JaiShreeRadhe&baba=HarHarMahadev HTTP/1.1" 200 -

# %% [markdown]
# http://192.168.29.193:5000/welcome?ram=JaiShriRam&radhe=JaiShreeRadhe&baba=HarHarMahadev
#
# ![image.png](attachment:image.png)

# %%
print("this print statement is just added to test the GIT command")
